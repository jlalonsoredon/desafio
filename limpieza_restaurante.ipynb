# %%
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv
import requests
import json

# %%
df_restaurantes = pd.read_csv("data/restaurantes_chiara_mal.csv")
df_restaurantes
# Out:
#      Unnamed: 0                    Nombre  \
# 0             0                  Agorregi
# 1             1                    Aizian
# 2             2                  Akelarre
# 3             3                   Alameda
# 4             4                 Almiketxu
# ..          ...                       ...
# 485         765         Quesería Soloitza
# 486         767       Larrañaga Gozotegia
# 487         772        Pastelería Sosoaga
# 488         773  Pastelería La Peña Dulce
# 489         775        Martina Zuricalday
#
#                                            Descripcion      Tipo de lugar  \
# 0    El restaurante Agorregi, ubicado en el barrio ...       restaurantes
# 1    Este moderno y acogedor restaurante fue diseña...       restaurantes
# 2    Pedro Subijana desarrolla desde 1970 una cocin...       restaurantes
# 3    La tercera generación es quien está a cargo de...       restaurantes
# 4    Es un caserío típico vasco y está regentado po...       restaurantes
# ...

# %%
df_tiendas = pd.read_csv("data/zonas_compras_limpio.csv")
df_tiendas
# Out:
#                       documentname  \
# 0                   Ezkur - Txerri
# 1                            Garoa
# 2                        Gazi Gozo
# 3                     Gaztaindizar
# 4                  Mahala Naturala
# ..                             ...
# 122  Real Sociedad (tienda Anoeta)
# 123  Real Sociedad (tienda Elkano)
# 124          Burutxaga Hestebeteak
# 125              Quesería Soloitza
# 126                   Jo Topagunea
#
#                                    documentdescription  \
# 0                                                  NaN
# 1    Queseria tradicional elaboradora de queso Idia...
# 2    Tienda de productos Gourmet de la tierra y de ...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 122                      Real Sociedad (tienda Anoeta)
# 123                      Real Sociedad (tienda Elkano)
# ...

# %%
# concatenamos buytype de df_tiendas en Tipo comida sin reducir el dataset de restaurantes
n_rows_before = len(df_restaurantes)

buytype_lookup = (
    df_tiendas[["documentname", "buytype"]]
    .dropna(subset=["documentname"])
)
buytype_lookup["documentname"] = buytype_lookup["documentname"].astype(str).str.strip()
buytype_lookup = (
    buytype_lookup.groupby("documentname", as_index=False)["buytype"]
    .agg(lambda s: " | ".join(dict.fromkeys(str(v).strip() for v in s if pd.notna(v) and str(v).strip())))
)

def concat_unique_types(tipo_actual, tipo_nuevo):
    values = []
    for value in [tipo_actual, tipo_nuevo]:
        if pd.isna(value):
            continue
        for part in str(value).split("|"):
            clean = part.strip()
            if clean and clean not in values:
                values.append(clean)
    return " | ".join(values) if values else pd.NA

def concat_unique_places(place_actual, place_new):
    values = []
    seen = set()
    for value in [place_actual, place_new]:
        if pd.isna(value):
            continue
        for part in str(value).replace("|", ",").split(","):
            clean = part.strip()
            key = clean.lower()
            if clean and key not in seen:
                values.append(clean)
                seen.add(key)
    return ", ".join(values) if values else pd.NA

# left merge: conserva todas las filas de df_restaurantes
df_restaurantes = df_restaurantes.merge(
    buytype_lookup.rename(columns={"documentname": "Nombre", "buytype": "buytype_match"}),
    on="Nombre",
    how="left"
 )

# solo concatenamos en filas comunes (donde hay match)
mask_match = df_restaurantes["buytype_match"].notna()
df_restaurantes.loc[mask_match, "Tipo comida"] = df_restaurantes.loc[mask_match].apply(
    lambda row: concat_unique_types(row.get("Tipo comida"), row.get("buytype_match")),
    axis=1
)

has_tienda = df_restaurantes["Tipo de lugar"].fillna("").str.lower().str.contains(r"\btienda(?:s)?\b", regex=True)
df_restaurantes.loc[mask_match & ~has_tienda, "Tipo de lugar"] = df_restaurantes.loc[
    mask_match & ~has_tienda, "Tipo de lugar"
].apply(lambda x: concat_unique_places(x, "tienda"))

df_restaurantes.drop(columns=["buytype_match"], inplace=True)

n_rows_after = len(df_restaurantes)
if n_rows_after != n_rows_before:
    raise ValueError(f"El dataset se redujo de {n_rows_before} a {n_rows_after} filas")

# %%
df_restaurantes
# Out:
#      Unnamed: 0                    Nombre  \
# 0             0                  Agorregi
# 1             1                    Aizian
# 2             2                  Akelarre
# 3             3                   Alameda
# 4             4                 Almiketxu
# ..          ...                       ...
# 485         765         Quesería Soloitza
# 486         767       Larrañaga Gozotegia
# 487         772        Pastelería Sosoaga
# 488         773  Pastelería La Peña Dulce
# 489         775        Martina Zuricalday
#
#                                            Descripcion      Tipo de lugar  \
# 0    El restaurante Agorregi, ubicado en el barrio ...       restaurantes
# 1    Este moderno y acogedor restaurante fue diseña...       restaurantes
# 2    Pedro Subijana desarrolla desde 1970 una cocin...       restaurantes
# 3    La tercera generación es quien está a cargo de...       restaurantes
# 4    Es un caserío típico vasco y está regentado po...       restaurantes
# ...

# %% [markdown]
# ## RESTAURANTES

# %%
import re
import unicodedata
import requests

n_rows_before = len(df_restaurantes)
url = "https://opendata.euskadi.eus/contenidos/ds_recursos_turisticos/restaurantes_sidrerias_bodegas/opendata/restaurantes.geojson"

resp = requests.get(url, timeout=30)
resp.raise_for_status()
geojson_data = resp.json()

properties = pd.json_normalize([f.get("properties", {}) for f in geojson_data.get("features", [])])

candidate_name_cols = ["documentname", "nameeu", "namees", "name", "Nombre"]
name_col = next((c for c in candidate_name_cols if c in properties.columns), None)
if name_col is None or "restorationtype" not in properties.columns:
    raise KeyError("No se encontraron columnas de nombre/restorationtype en el GeoJSON")

def normalize_name(text):
    text = "" if pd.isna(text) else str(text)
    text = unicodedata.normalize("NFKD", text).encode("ascii", "ignore").decode("utf-8")
    text = re.sub(r"\s+", " ", text).strip().lower()
    return text

geo_types = (
    properties[[name_col, "restorationtype"]]
    .dropna(subset=[name_col])
    .rename(columns={name_col: "nombre_geo"})
)
geo_types["nombre_key"] = geo_types["nombre_geo"].apply(normalize_name)
geo_types = (
    geo_types.groupby("nombre_key", as_index=False)["restorationtype"]
    .agg(lambda s: " | ".join(dict.fromkeys(str(v).strip() for v in s if pd.notna(v) and str(v).strip())))
)

df_restaurantes["nombre_key"] = df_restaurantes["Nombre"].apply(normalize_name)
restoration_map = geo_types.set_index("nombre_key")["restorationtype"]
df_restaurantes["restorationtype_match"] = df_restaurantes["nombre_key"].map(restoration_map)

mask_match = df_restaurantes["restorationtype_match"].notna()
df_restaurantes.loc[mask_match, "Tipo comida"] = df_restaurantes.loc[mask_match].apply(
    lambda row: concat_unique_types(row.get("Tipo comida"), row.get("restorationtype_match")),
    axis=1
)

df_restaurantes.drop(columns=["nombre_key", "restorationtype_match"], inplace=True)

n_rows_after = len(df_restaurantes)
if n_rows_after != n_rows_before:
    raise ValueError(f"El dataset se redujo de {n_rows_before} a {n_rows_after} filas")

# %%
df_restaurantes[["Nombre","Municipio","Descripcion", "Tipo de lugar", "Tipo comida", "WEB"]]
# Out:
#                        Nombre      Municipio  \
# 0                    Agorregi  San Sebastián
# 1                      Aizian         Bilbao
# 2                    Akelarre  San Sebastián
# 3                     Alameda    Hondarribia
# 4                   Almiketxu         Bermeo
# ..                        ...            ...
# 485         Quesería Soloitza          Ayala
# 486       Larrañaga Gozotegia        Bergara
# 487        Pastelería Sosoaga        Vitoria
# 488  Pastelería La Peña Dulce        Vitoria
# 489        Martina Zuricalday         Bilbao
#
#                                            Descripcion      Tipo de lugar  \
# 0    El restaurante Agorregi, ubicado en el barrio ...       restaurantes
# 1    Este moderno y acogedor restaurante fue diseña...       restaurantes
# 2    Pedro Subijana desarrolla desde 1970 una cocin...       restaurantes
# 3    La tercera generación es quien está a cargo de...       restaurantes
# ...

# %%
export_path = "data/restaurantes_limpio_jose.csv"
df_restaurantes.to_csv(export_path, index=False)

# %% [markdown]
# ## Estrellas

# %%
df_gastro = pd.read_csv("data/restaurantes_limpio_jose.csv")
df_gastro
# Out:
#      Unnamed: 0                    Nombre  \
# 0             0                  Agorregi
# 1             1                    Aizian
# 2             2                  Akelarre
# 3             3                   Alameda
# 4             4                 Almiketxu
# ..          ...                       ...
# 485         765         Quesería Soloitza
# 486         767       Larrañaga Gozotegia
# 487         772        Pastelería Sosoaga
# 488         773  Pastelería La Peña Dulce
# 489         775        Martina Zuricalday
#
#                                            Descripcion  Dirección  \
# 0    El restaurante Agorregi, ubicado en el barrio ...        NaN
# 1    Este moderno y acogedor restaurante fue diseña...        NaN
# 2    Pedro Subijana desarrolla desde 1970 una cocin...        NaN
# 3    La tercera generación es quien está a cargo de...        NaN
# 4    Es un caserío típico vasco y está regentado po...        NaN
# ...

# %%
restaurantesMichelin = [
  { "nombre": "Akelarre", "poblacion": "San Sebastián" },
  { "nombre": "Arzak", "poblacion": "San Sebastián" },
  { "nombre": "Azurmendi", "poblacion": "Larrabetzu" },
  { "nombre": "Martín Berasategui", "poblacion": "Lasarte-Oria" },
  { "nombre": "Amelia by Paulo Airaudo", "poblacion": "San Sebastián" },
  { "nombre": "Mugaritz", "poblacion": "Errenteria" },
  { "nombre": "Bakea", "poblacion": "Mungia" },
  { "nombre": "Islares", "poblacion": "Bilbao" },
  { "nombre": "Itzuli", "poblacion": "San Sebastián" },
  { "nombre": "La Revelía", "poblacion": "Amorebieta-Etxano" },
  { "nombre": "Alameda", "poblacion": "Hondarribia" },
  { "nombre": "Ama", "poblacion": "Tolosa" },
  { "nombre": "Andra Mari", "poblacion": "Galdakao" },
  { "nombre": "ARREA!", "poblacion": "Santa Cruz de Campezo" },
  { "nombre": "Boroa", "poblacion": "Amorebieta-Etxano" },
  { "nombre": "Elkano", "poblacion": "Getaria" },
  { "nombre": "Eneko", "poblacion": "Larrabetzu" },
  { "nombre": "Etxebarri", "poblacion": "Axpe" },
  { "nombre": "Garena", "poblacion": "Dima" },
  { "nombre": "iBAi", "poblacion": "San Sebastián" },
  { "nombre": "Kokotxa", "poblacion": "San Sebastián" },
  { "nombre": "Mina", "poblacion": "Bilbao" },
  { "nombre": "Nerua Guggenheim Bilbao", "poblacion": "Bilbao" },
  { "nombre": "Ola Martín Berasategui", "poblacion": "Bilbao" },
  { "nombre": "Txispa", "poblacion": "Axpe" },
  { "nombre": "Zarate", "poblacion": "Bilbao" }
];

# %%
import re
import unicodedata

def normalize_text(value):
    text = "" if pd.isna(value) else str(value)
    text = unicodedata.normalize("NFKD", text).encode("ascii", "ignore").decode("utf-8")
    text = text.lower().strip()
    text = re.sub(r"\s+", " ", text)
    return text

def asignar_michelin(df, restaurantes_array):
    municipio_candidates = ["Poblacion", "Población", "Municipio", "municipio", "poblacion"]
    municipio_col = next((c for c in municipio_candidates if c in df.columns), None)
    if municipio_col is None:
        raise KeyError("No se encontro columna de poblacion/municipio en df_gastro")

    df = df.copy()
    df["Michelin"] = 0

    match_keys = {
        (normalize_text(item.get("nombre")), normalize_text(item.get("poblacion")))
        for item in restaurantes_array
    }

    df_keys = pd.Series(
        list(zip(df["Nombre"].map(normalize_text), df[municipio_col].map(normalize_text))),
        index=df.index
    )
    df.loc[df_keys.isin(match_keys), "Michelin"] = 1

    found_keys = set(df_keys[df["Michelin"] == 1].tolist())
    for item in restaurantes_array:
        key = (normalize_text(item.get("nombre")), normalize_text(item.get("poblacion")))
        estado = "ENCONTRADO" if key in found_keys else "NO ENCONTRADO"
        print(f"{estado}: {item.get('nombre')} - {item.get('poblacion')}")

    return df

df_gastro = asignar_michelin(df_gastro, restaurantesMichelin)
df_gastro[["Nombre", "Michelin"]].head()
# Out:
# ENCONTRADO: Akelarre - San Sebastián
# ENCONTRADO: Arzak - San Sebastián
# ENCONTRADO: Azurmendi - Larrabetzu
# ENCONTRADO: Martín Berasategui - Lasarte-Oria
# ENCONTRADO: Amelia by Paulo Airaudo - San Sebastián
# NO ENCONTRADO: Mugaritz - Errenteria
# NO ENCONTRADO: Bakea - Mungia
# NO ENCONTRADO: Islares - Bilbao
# NO ENCONTRADO: Itzuli - San Sebastián
# ENCONTRADO: La Revelía - Amorebieta-Etxano
# ENCONTRADO: Alameda - Hondarribia
# ENCONTRADO: Ama - Tolosa
# ENCONTRADO: Andra Mari - Galdakao
# NO ENCONTRADO: ARREA! - Santa Cruz de Campezo
# NO ENCONTRADO: Boroa - Amorebieta-Etxano
# ENCONTRADO: Elkano - Getaria
# ENCONTRADO: Eneko - Larrabetzu
# NO ENCONTRADO: Etxebarri - Axpe
# ENCONTRADO: Garena - Dima
# NO ENCONTRADO: iBAi - San Sebastián
# ENCONTRADO: Kokotxa - San Sebastián
# ENCONTRADO: Mina - Bilbao
# NO ENCONTRADO: Nerua Guggenheim Bilbao - Bilbao
# ENCONTRADO: Ola Martín Berasategui - Bilbao
# NO ENCONTRADO: Txispa - Axpe
# ENCONTRADO: Zarate - Bilbao
# ...

# %%
df_gastro[["Nombre", "Municipio", "Michelin"]]
# Out:
#                        Nombre      Municipio  Michelin
# 0                    Agorregi  San Sebastián         0
# 1                      Aizian         Bilbao         0
# 2                    Akelarre  San Sebastián         1
# 3                     Alameda    Hondarribia         1
# 4                   Almiketxu         Bermeo         0
# ..                        ...            ...       ...
# 485         Quesería Soloitza          Ayala         0
# 486       Larrañaga Gozotegia        Bergara         0
# 487        Pastelería Sosoaga        Vitoria         0
# 488  Pastelería La Peña Dulce        Vitoria         0
# 489        Martina Zuricalday         Bilbao         0
#
# [490 rows x 3 columns]

# %%
restaurantes_repsol = [
    # --- GUIPÚZCOA ---
    {"nombre": "Akelarre", "poblacion": "San Sebastián"},
    {"nombre": "Arzak", "poblacion": "San Sebastián"},
    {"nombre": "Elkano", "poblacion": "Getaria"},
    {"nombre": "Martín Berasategui", "poblacion": "Lasarte-Oria"},
    {"nombre": "Mugaritz", "poblacion": "Errenteria"},
    {"nombre": "Alameda", "poblacion": "Hondarribia"},
    {"nombre": "AMA Tolosa", "poblacion": "Tolosa"},
    {"nombre": "Bodega Katxiña", "poblacion": "Orio"},
    {"nombre": "Casa Julián – Matías Gorrotxategi", "poblacion": "Tolosa"},
    {"nombre": "Casa Urola", "poblacion": "San Sebastián"},
    {"nombre": "Hika Gastronomiko", "poblacion": "Villabona"},
    {"nombre": "Kaia-Kaipe", "poblacion": "Getaria"},
    {"nombre": "Kokotxa", "poblacion": "San Sebastián"},
    {"nombre": "Laia Erretegia", "poblacion": "Hondarribia"},
    {"nombre": "Mirador de Ulía", "poblacion": "San Sebastián"},
    {"nombre": "Narru", "poblacion": "San Sebastián"},
    {"nombre": "Rekondo", "poblacion": "San Sebastián"},
    {"nombre": "Aiten Etxe", "poblacion": "Zarautz"},
    {"nombre": "Araneta", "poblacion": "Zestoa"},
    {"nombre": "Asador Landa", "poblacion": "Mendaro"},
    {"nombre": "Asador Nicolás", "poblacion": "Tolosa"},
    {"nombre": "Astelena 1997", "poblacion": "San Sebastián"},
    {"nombre": "Bailara", "poblacion": "Bidania-Goiatz"},
    {"nombre": "Casa Cámara", "poblacion": "Pasaia"},
    {"nombre": "Espazio Oteiza-Akelarre", "poblacion": "San Sebastián"},
    {"nombre": "Etxeberri", "poblacion": "Zumárraga"},
    {"nombre": "Fagollaga", "poblacion": "Hernani"},
    {"nombre": "Ganbara", "poblacion": "San Sebastián"},
    {"nombre": "Hamarratz", "poblacion": "Zumaia"},
    {"nombre": "Iriarte", "poblacion": "Berrobi"},
    {"nombre": "Itzuli", "poblacion": "Donostia-San Sebastián"},
    {"nombre": "Kirkilla Enea", "poblacion": "Zarautz"},
    {"nombre": "Muka", "poblacion": "San Sebastián"},
    {"nombre": "Sukaldean Aitor Santamaria", "poblacion": "Donostia-San Sebastián"},
    {"nombre": "Sutan", "poblacion": "Hondarribia"},
    {"nombre": "Zazpi STM", "poblacion": "San Sebastián"},
    {"nombre": "Zelai Txiki", "poblacion": "San Sebastián"},

    # --- VIZCAYA ---
    {"nombre": "Azurmendi", "poblacion": "Larrabetzu"},
    {"nombre": "Etxebarri", "poblacion": "Atxondo"},
    {"nombre": "Nerua Guggenheim Bilbao", "poblacion": "Bilbao"},
    {"nombre": "Andra Mari", "poblacion": "Galdakao"},
    {"nombre": "Atelier Etxanobe", "poblacion": "Bilbao"},
    {"nombre": "Bakea", "poblacion": "Mungia"},
    {"nombre": "Boroa", "poblacion": "Amorebieta-Etxano"},
    {"nombre": "Garena", "poblacion": "Dima"},
    {"nombre": "Mina", "poblacion": "Bilbao"},
    {"nombre": "Zarate", "poblacion": "Bilbao"},
    {"nombre": "Aitor Rauleaga", "poblacion": "Bilbao"},
    {"nombre": "Amaren", "poblacion": "Bilbao"},
    {"nombre": "Aretxondo", "poblacion": "Galdakao"},
    {"nombre": "Baserri Maitea", "poblacion": "Forua"},
    {"nombre": "Casa Garras", "poblacion": "Valle de Carranza"},
    {"nombre": "El Paladar by Zuriñe García", "poblacion": "Portugalete"},
    {"nombre": "Eneko", "poblacion": "Larrabetzu"},
    {"nombre": "Gotzon Jatetxea", "poblacion": "Bakio"},
    {"nombre": "Horma Ondo", "poblacion": "Larrabetzu"},
    {"nombre": "Islares", "poblacion": "Bilbao"},
    {"nombre": "Jauregibarria", "poblacion": "Amorebieta"},
    {"nombre": "Kuma", "poblacion": "Bilbao"},
    {"nombre": "La Despensa del Etxanobe", "poblacion": "Bilbao"},
    {"nombre": "Mendi Goikoa Bekoa", "poblacion": "Atxondo"},
    {"nombre": "Ola Martín Berasategui", "poblacion": "Bilbao"},
    {"nombre": "Porrue", "poblacion": "Bilbao"},
    {"nombre": "Remenetxe", "poblacion": "Muxica"},
    {"nombre": "Tamarises Izarra", "poblacion": "Getxo"},
    {"nombre": "Txispa", "poblacion": "Atxondo"},
    {"nombre": "Yandiola", "poblacion": "Bilbao"},

    # --- ÁLAVA ---
    {"nombre": "Arrea!", "poblacion": "Santa Cruz de Campezo"},
    {"nombre": "Bideko", "poblacion": "Lezama"},
    {"nombre": "Karmine", "poblacion": "Vitoria-Gasteiz"},
    {"nombre": "KEA Basque Fine Food", "poblacion": "Vitoria-Gasteiz"},
    {"nombre": "Kromatiko", "poblacion": "Vitoria-Gasteiz"},
    {"nombre": "Marqués de Riscal", "poblacion": "Elciego"},
    {"nombre": "Tierra y vino", "poblacion": "Samaniego"},
    {"nombre": "Zaldiarán", "poblacion": "Vitoria-Gasteiz"}
]

# %%
import re
import unicodedata

def normalize_text(value):
    text = "" if pd.isna(value) else str(value)
    text = unicodedata.normalize("NFKD", text).encode("ascii", "ignore").decode("utf-8")
    text = text.lower().strip()
    text = re.sub(r"\s+", " ", text)
    return text

def asignar_Repsol(df, restaurantes_array):
    municipio_candidates = ["Poblacion", "Población", "Municipio", "municipio", "poblacion"]
    municipio_col = next((c for c in municipio_candidates if c in df.columns), None)
    if municipio_col is None:
        raise KeyError("No se encontro columna de poblacion/municipio en df_gastro")

    df = df.copy()
    df["Repsol"] = 0

    match_keys = {
        (normalize_text(item.get("nombre")), normalize_text(item.get("poblacion")))
        for item in restaurantes_array
    }

    df_keys = pd.Series(
        list(zip(df["Nombre"].map(normalize_text), df[municipio_col].map(normalize_text))),
        index=df.index
    )
    df.loc[df_keys.isin(match_keys), "Repsol"] = 1

    found_keys = set(df_keys[df["Repsol"] == 1].tolist())
    for item in restaurantes_array:
        key = (normalize_text(item.get("nombre")), normalize_text(item.get("poblacion")))
        estado = "ENCONTRADO" if key in found_keys else "NO ENCONTRADO"
        print(f"{estado}: {item.get('nombre')} - {item.get('poblacion')}")

    return df

df_gastro = asignar_Repsol(df_gastro, restaurantes_repsol)
df_gastro[["Nombre", "Repsol"]].head()
# Out:
# ENCONTRADO: Akelarre - San Sebastián
# ENCONTRADO: Arzak - San Sebastián
# ENCONTRADO: Elkano - Getaria
# ENCONTRADO: Martín Berasategui - Lasarte-Oria
# NO ENCONTRADO: Mugaritz - Errenteria
# ENCONTRADO: Alameda - Hondarribia
# NO ENCONTRADO: AMA Tolosa - Tolosa
# ENCONTRADO: Bodega Katxiña - Orio
# NO ENCONTRADO: Casa Julián – Matías Gorrotxategi - Tolosa
# ENCONTRADO: Casa Urola - San Sebastián
# NO ENCONTRADO: Hika Gastronomiko - Villabona
# NO ENCONTRADO: Kaia-Kaipe - Getaria
# ENCONTRADO: Kokotxa - San Sebastián
# ENCONTRADO: Laia Erretegia - Hondarribia
# ENCONTRADO: Mirador de Ulía - San Sebastián
# ENCONTRADO: Narru - San Sebastián
# ENCONTRADO: Rekondo - San Sebastián
# NO ENCONTRADO: Aiten Etxe - Zarautz
# NO ENCONTRADO: Araneta - Zestoa
# NO ENCONTRADO: Asador Landa - Mendaro
# ENCONTRADO: Asador Nicolás - Tolosa
# NO ENCONTRADO: Astelena 1997 - San Sebastián
# NO ENCONTRADO: Bailara - Bidania-Goiatz
# ENCONTRADO: Casa Cámara - Pasaia
# ...

# %%
df_gastro[["Nombre", "Municipio", "Michelin", "Repsol"]]
# Out:
#                        Nombre      Municipio  Michelin  Repsol
# 0                    Agorregi  San Sebastián         0       0
# 1                      Aizian         Bilbao         0       0
# 2                    Akelarre  San Sebastián         1       1
# 3                     Alameda    Hondarribia         1       1
# 4                   Almiketxu         Bermeo         0       0
# ..                        ...            ...       ...     ...
# 485         Quesería Soloitza          Ayala         0       0
# 486       Larrañaga Gozotegia        Bergara         0       0
# 487        Pastelería Sosoaga        Vitoria         0       0
# 488  Pastelería La Peña Dulce        Vitoria         0       0
# 489        Martina Zuricalday         Bilbao         0       0
#
# [490 rows x 4 columns]

# %%
export_path = "data/restaurantes_limpio_jose.csv"
df_gastro.to_csv(export_path, index=False)

# %%
df_gastronomia = pd.read_csv("data/restaurantes_limpio_jose_michelin.csv")
df_gastronomia
# Out:
#      Unnamed: 0                    Nombre  \
# 0             0                  Agorregi
# 1             1                    Aizian
# 2             2                  Akelarre
# 3             3                   Alameda
# 4             4                 Almiketxu
# ..          ...                       ...
# 485         765         Quesería Soloitza
# 486         767       Larrañaga Gozotegia
# 487         772        Pastelería Sosoaga
# 488         773  Pastelería La Peña Dulce
# 489         775        Martina Zuricalday
#
#                                            Descripcion  Dirección  \
# 0    El restaurante Agorregi, ubicado en el barrio ...        NaN
# 1    Este moderno y acogedor restaurante fue diseña...        NaN
# 2    Pedro Subijana desarrolla desde 1970 una cocin...        NaN
# 3    La tercera generación es quien está a cargo de...        NaN
# 4    Es un caserío típico vasco y está regentado po...        NaN
# ...

# %%
# vamos a hacer un replace de hppt por https en la columna WEB para evitar problemas de validacion de url
df_gastronomia["WEB"] = df_gastronomia["WEB"].str.replace(r"^hppt://", "https://", regex=True)

# %%
load_dotenv()
API_KEY = os.getenv("API_KEY_MAPS")

# %%
def safe_json(response, context="request"):
    """Devuelve JSON seguro; imprime errores de estado/parsing y retorna None si falla."""
    try:
        response.raise_for_status()
    except requests.HTTPError as exc:
        print(f"[HTTP {response.status_code}] {context}: {exc}")
        return None

    try:
        return response.json()
    except ValueError:
        print(f"[JSON ERROR] {context}: respuesta no valida")
        return None


def search_place_id(nombre, municipio, lat, log, web, api_key):
    """Busca Place ID en Google Places. Primero por nombre+municipio y luego por web."""
    payload = {"textQuery": f"{nombre}, {municipio}"}
    if pd.notna(lat) and pd.notna(log):
        payload["locationBias"] = {
            "circle": {
                "center": {"latitude": float(lat), "longitude": float(log)},
                "radius": 500.0
            }
        }

    r = requests.post(
        "https://places.googleapis.com/v1/places:searchText",
        json=payload,
        headers={
            "Content-Type": "application/json",
            "X-Goog-Api-Key": api_key,
            "X-Goog-FieldMask": "places.id"
        },
        timeout=20
    )
    places = (safe_json(r, f"search '{nombre}'") or {}).get("places", [])

    if not places and web:
        print(f"[FALLBACK web] '{nombre}' -> {web}")
        r2 = requests.post(
            "https://places.googleapis.com/v1/places:searchText",
            json={"textQuery": str(web)},
            headers={
                "Content-Type": "application/json",
                "X-Goog-Api-Key": api_key,
                "X-Goog-FieldMask": "places.id"
            },
            timeout=20
        )
        places = (safe_json(r2, f"search web '{nombre}'") or {}).get("places", [])

    return places[0]["id"] if places else None


def get_place_details(place_id, api_key):
    """Obtiene solo la direccion formateada de un Place ID."""
    r = requests.get(
        f"https://places.googleapis.com/v1/places/{place_id}",
        headers={
            "X-Goog-Api-Key": api_key,
            "X-Goog-FieldMask": "formattedAddress"
        },
        timeout=20
    )
    return safe_json(r, f"details '{place_id}'")


def enrich_dataframe(df, api_key, limit=None):
    """Enriquece SOLO la columna Direccion usando Google Places API."""
    if not api_key:
        raise ValueError("API_KEY_MAPS no esta configurada")

    df = df.copy()
    df["Dirección"] = pd.Series(df.get("Dirección", ""), index=df.index, dtype="object")

    subset = df.head(limit) if limit else df
    cont_ok, cont_ko = 0, 0

    for idx, row in subset.iterrows():
        nombre = row.get("Nombre")
        municipio = row.get("Municipio")
        lat = row.get("lat")
        log = row.get("log")
        web = row.get("WEB") if pd.notna(row.get("WEB")) and str(row.get("WEB")).strip() else None

        place_id = search_place_id(nombre, municipio, lat, log, web, api_key)
        if not place_id:
            print(f"[SKIP] sin resultados para '{nombre}'")
            continue

        details = get_place_details(place_id, api_key)
        if not details:
            print(f"[SKIP] sin direccion para '{nombre}'")
            cont_ko += 1
            continue

        df.at[idx, "Dirección"] = details.get("formattedAddress", "")
        cont_ok += 1
        print(f"[OK] '{nombre}' -> {df.at[idx, 'Dirección']} (ok: {cont_ok})")

    print("\n--- RESUMEN ---")
    print(f"Direcciones enriquecidas: {cont_ok} / {len(subset)} | Fallos: {cont_ko}")
    return df

# %%
df_gastronomia_direc = enrich_dataframe(df_gastronomia, API_KEY)

# %%
df_gastronomia_test = enrich_dataframe(df_gastronomia, API_KEY, limit=5)
df_gastronomia_test[["Nombre", "Municipio", "Dirección"]].head(5)
# Out:
# [OK] 'Agorregi' -> Portuetxe K., 14, 20018 Donostia / San Sebastián, Gipuzkoa, Spain (ok: 1)
# [OK] 'Aizian' -> Leizaola Lehendakariaren Kalea, 29, Abando, 48001 Bilbao, Bizkaia, Spain (ok: 2)
# [OK] 'Akelarre' -> Padre Orkolaga Ibilbidea, 56, 20008 Donostia / San Sebastián, Gipuzkoa, Spain (ok: 3)
# [OK] 'Alameda' -> Minasoroeta Kalea, 1, 20280, Gipuzkoa, Spain (ok: 4)
# [OK] 'Almiketxu' -> Almike Auzoa, 8, 48370 Bermeo, Bizkaia, Spain (ok: 5)
#
# --- RESUMEN ---
# Direcciones enriquecidas: 5 / 5 | Fallos: 0
#       Nombre      Municipio                                          Dirección
# 0   Agorregi  San Sebastián  Portuetxe K., 14, 20018 Donostia / San Sebasti...
# 1     Aizian         Bilbao  Leizaola Lehendakariaren Kalea, 29, Abando, 48...
# 2   Akelarre  San Sebastián  Padre Orkolaga Ibilbidea, 56, 20008 Donostia /...
# 3    Alameda    Hondarribia       Minasoroeta Kalea, 1, 20280, Gipuzkoa, Spain
# ...
