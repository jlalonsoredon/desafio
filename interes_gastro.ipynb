# %%
import pandas as pd

# %%
df = pd.read_csv('data/gastronomy_qualifications.csv', sep= ' ')
df
# Out:
#     Michelin\tRepsol\tDenominación de Origen\tAgricultura Ecológica\tEuskal Baserri\tEusko Label
# 0                                         0\t0\t\t\t\t
# 1                                         0\t0\t\t\t\t
# 2                                         1\t1\t\t\t\t
# 3                                         1\t1\t\t\t\t
# 4                                         0\t0\t\t\t\t
# ..                                                 ...
# 485                            0\t0\tEusko Label\t\t\t
# 486                 0\t0\tDenominación de Origen\t\t\t
# 487                 0\t0\tDenominación de Origen\t\t\t
# 488                 0\t0\tDenominación de Origen\t\t\t
# 489                 0\t0\tDenominación de Origen\t\t\t
#
# [490 rows x 1 columns]
